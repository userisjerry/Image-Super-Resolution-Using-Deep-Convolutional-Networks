# %%
# RGBchannel을 그대로 입력받는 모델을 구현
# filter number에 대한 실험 결과 참고 -> n1=128, n2=64, n3=3 ;; n-각 convolution layer의 필터 숫자
# filter size에 대한 실험 결과 참고 -> f1=9, f2=3, f3=5 ;; f-filter size
# 순서대로 ReLU, 마지막은 Linear
# 논문 조건대로 weight : Xaiver 정규 분포, bias : 제로 벡터로 초기화
# learning rate -> 0.003 일괄 통일
# SRCNN의 저해상도 이미지 -> 고해상도 이미지를 Random crop -> Bicubic보간법으로 upscaling된 이미지
# kaggle에 91 Images활용 // https://www.kaggle.com/datasets/ll01dm/t91-image-dataset
# 검증 데이터도 논문과 동일한 set5 // https://www.kaggle.com/datasets/ll01dm/set-5-14-super-resolution-dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py # hdf5   대규모 데이터 세트 관리
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, Input
from keras import initializers
from keras.optimizers import Adam  ## adam : 옵티마이저;학습속도 조절, 모델성능 최적화
import random


import cv2
import os
from glob import glob  ## glob는 데이터셋이 저장된 path에서 '.png'로 끝나는 파일의 목록 반환

# %%
# connecting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd # current position
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !mkdir srcnn
# Out:
# mkdir: cannot create directory ‘srcnn’: File exists

# %%
# %cd /content/drive/srcnn
# Out:
# [Errno 2] No such file or directory: '/content/drive/srcnn'
# /content/drive/MyDrive

# %%
# !pwd # current position
# Out:
# /content/drive/MyDrive

# %%
# %cd /content/drive/MyDrive/srcnn
# Out:
# /content/drive/MyDrive/srcnn

# %%
# 파라미터 선언
# path : 91 image dataset 저장 경로
# save_path : 최종 모델의 가중치 저장 경로

# %%
n1, n2, n3 = 128, 64, 3
f1, f2, f3 = 9, 3, 5
upscale_factor = 2

input_size = 33
output_size = input_size - f1 - f2 - f3 + 3
pad = abs(input_size - output_size) // 2
stride = 14

batch_size = 128
epochs = 200

# %%
path = '/content/drive/MyDrive/srcnn/T91'
save_path = '/content/drive/MyDrive/srcnn/Set5'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 데이터셋 load 및 확인
img_paths = glob(path + '/' + '*.png')

img = cv2.imread(img_paths[0])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
#img = cv2.imread(img_paths[0], cv2.COLOR_BGR2RGB)
## 이 코드에서 cv2.COLOR_BGR2RGB를 전달하면 이미지 읽기 모드로 해석되지 않아, 오류가 발생하거나 전혀 다른 결과를 초래
#3 openCV의 imread 함수는 두 번째 인수로 색상 변환 코드를 받아들이지 않습니다
#plt.imshow(img)

# %%
# 저해상도 이미지 만들기
# srcnn의 학습은 저해상도 이미지와 고해상도 이미지를 각각 sub images로 crop하고
# 이들간의 관계를 학습

# 즉, crop -> mapping

# %%
sub_lr_images = []
sub_hr_images = []

for img_path in img_paths:
    img = cv2.imread(img_path)   ## 08.12. 2차 수정
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


# mod crop
h = img.shape[0] - np.mod(img.shape[0], upscale_factor)
w = img.shape[1] - np.mod(img.shape[1], upscale_factor)
# 이미지의 높이(h)와 너비(w)를 업스케일 팩터(upscale_factor)의 배수가 되도록 조정합니다.
#np.mod를 사용하여 이미지 크기가 업스케일 팩터로 나누어 떨어지지 않는 부분을 잘라냅니다.
#
img = img[0:h, 0:w, :]

# zoom_img
label = img.astype('float')/ 255   ## (0,1)값으로 정규화

temp_input = cv2.resize(label,dsize=(0,0),fx=1/upscale_factor,
                        fy=1/upscale_factor,interpolation=cv2.INTER_AREA)  #area 는 축소 보간법 : 노이즈 줄임
# 다운스케일링해서 저해상도 이미지 만듬
input = cv2.resize(temp_input, dsize=(0,0),fx=upscale_factor,
                        fy=upscale_factor, interpolation=cv2.INTER_CUBIC)  #cubic은 이미지 확대 : 확대시 부드럽고 선명한 이미지
# 업스케일링하여 원래 크기로 되돌린다 -> 해상도가 낮아진 이미지를 복원
### 보간 방식: INTER_AREA는 영역 평균을 사용하고, INTER_CUBIC은 다항식을 사용합니다.

# crop : img to sub_imgs
for h in range(0, input.shape[0] - input_size + 1, stride):
    for w in range(0, input.shape[1] - input_size + 1, stride):
        sub_lr_img = input[h:h+input_size, w:w+input_size, :]
        sub_hr_img = label[h+pad:h+pad+output_size, w+pad:w+pad+output_size, :]
# 작은 조각으로 잘라, stride에 따라 중첩되게
# sub_hr_img pad만큼 패딩을 고려하여 자른다

        sub_lr_images.append(sub_lr_img)
        sub_hr_images.append(sub_hr_img)

sub_lr_imgs = np.array(sub_lr_images)
sub_hr_imgs = np.array(sub_hr_images)

# %%
# sub_lr_imgs

# %%
# crop된 저해상도, 고해상도 paired 이미지 확인

# %%
fig, axes = plt.subplots(1,2, figsize=(5,5))
idx = random.randint(0, sub_lr_imgs.shape[0]-1)
## [0]을 스지 않는 오류 -> 끝값은 유효한 인덱스가 아니라서 index error 발생 가능


axes[0].imshow(sub_lr_imgs[idx])
axes[1].imshow(sub_hr_imgs[idx])

print(idx)
axes[0].set_title('sub_lr_imgs')
axes[1].set_title('sub_hr_imgs')

## 고 : 픽셀 수가 많아서 이미지를 확대해도 픽셀이 눈에 잘 띄지 않고, 디테일이 잘 보존
###사진, 영상, 그래픽 등에서 고해상도는 선명하고 깨끗한 이미지를 제공

## 저 : 픽셀 수가 적어서 이미지를 확대하면 픽셀이 눈에 잘 띄고, 디테일이 부족
###저해상도는 이미지가 흐릿하게 보일 수 있으며, 세부사항이 잘 드러나지 않음
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 528
# Text(0.5, 1.0, 'sub_hr_imgs')

# %%
# 모델 선언 및 파라미터 초기화

### GloroNormal은 Xaiver 정규분포를 의미

# %%
initializer = initializers.GlorotNormal()
## 가중치 - 정규분포로 초기화
## 편향 - 0으로 초기화

SRCNN = Sequential()
# SRCNN.add(Input(shpae=(33,33,3)))
SRCNN.add(Conv2D(filters=n1, kernel_size=f1, activation='relu',
                 input_shape=(33,33,3), kernel_initializer=initializer,
                 bias_initializer='zeros', name='conv1'))
## 첫번째 layer은 저해상도 이미지를 입력받아서
## patch extraction and representation 역할을 수행
## 논문에서는 이 과정이 저해상도 이미지로부터 여러 패치를 추출하고 이를 feature map의 집합으로 바꾼다한다
## 쉽게 conv layer가 저해상도 이미진느 scan한다고 생각함녀 된다
## cnn의 특성상 이렇게 추출된 feature map은 일종의 representation이 되는 데
## 논문에서는 이 feature map들이 저해상도 이미지 패치의 표현

SRCNN.add(Conv2D(filters=n2, kernel_size=f2, activation='relu',
                 kernel_initializer=initializer, bias_initializer='zeros', name='conv2'))
## 저해상도 이미지 패치의 표현,
## feature map들을 non-linear mapping하여 고해상도 패치의 표현으로 변환하는 역할

SRCNN.add(Conv2D(filters=n3, kernel_size=f3, activation='linear',
                 kernel_initializer=initializer, bias_initializer='zeros', name='conv3'))
## 고해상도 패치의 표현들
## featyre map으로부터 최종 고해상도 이미지를 reconstruction하는 역할을 한다
## 그리고 이렇게 복원된 이미지, f(y)가 원본 고해상도 이미지x 와 유사하다면 학습은 성공적인것


print(SRCNN.summary())

## < SRCNN Model 구조 >
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1 (Conv2D)                       │ (None, 25, 25, 128)         │          31,232 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2 (Conv2D)                       │ (None, 23, 23, 64)          │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3 (Conv2D)                       │ (None, 19, 19, 3)           │           4,803 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 109,827 (429.01 KB)
#  Trainable params: 109,827 (429.01 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
#    Input Image
#      (33x33x3)
#         |
#         V
#[Conv2D: 9x9 filters, 128 filters, ReLU]
#      (25x25x128)  <- Feature maps after this layer
#         |
#         V
#[Conv2D: 3x3 filters, 64 filters, ReLU]
#      (23x23x64)   <- Feature maps after this layer
#         |
#         V
#[Conv2D: 5x5 filters, 3 filters, Linear]
#      (21x21x3)    <- Output image
#

# %% [markdown]
# .

# %%
# model compile or fit

## epoch을 몇 번 돌려볼까?
## 기존 코드에서 숫자만 바꿔서 더 돌려볼까?? (cell-11)

# %%
optimizer = Adam(learning_rate=0.0003)
SRCNN.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])

## compile 메서드는 모델의 학습과 평가를 설정
# 평균 제곱 오차를 손실 함수로 설정하며, 같은 평균 제곱 오차를 메트릭으로 모니터링
# 훈련 데이터를 기반으로 얼마나 잘 학습되고 있는지 평가

# %%
SRCNN.fit(sub_lr_imgs, sub_hr_imgs, batch_size=batch_size,
          epochs=epochs, verbose=1, # callbacks=[callbacks]
          )

## verbose=1: 학습 과정에서 출력의 상세 수준을 설정합니다. verbose=1은 에포크별로 훈련 과정의 진행 상황을 보여주는 정보를 출력합니다.
## verbose=0은 아무런 출력도 하지 않고, verbose=2는 에포크별로 자세한 정보를 출력

## callbacks를 넣는 이유?

## callbacks가 애초에 전과정에서 변수로 지정이 되어야 하는데 어디서 지정?
# Out:
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 0.1520 - mean_squared_error: 0.1520
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0237 - mean_squared_error: 0.0237
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 0.0188 - mean_squared_error: 0.0188
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 9.8695e-04 - mean_squared_error: 9.8695e-04
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 9.1311e-04 - mean_squared_error: 9.1311e-04
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 8.4347e-04 - mean_squared_error: 8.4347e-04
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 8.7935e-04 - mean_squared_error: 8.7935e-04
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 8.0406e-04 - mean_squared_error: 8.0406e-04
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 8.0461e-04 - mean_squared_error: 8.0461e-04
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - loss: 7.9935e-04 - mean_squared_error: 7.9935e-04
# Epoch 34/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 7.4348e-04 - mean_squared_error: 7.4348e-04
# Epoch 35/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 7.3834e-04 - mean_squared_error: 7.3834e-04
# Epoch 36/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 7.4941e-04 - mean_squared_error: 7.4941e-04
# Epoch 37/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 7.2495e-04 - mean_squared_error: 7.2495e-04
# Epoch 38/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 7.4357e-04 - mean_squared_error: 7.4357e-04
# Epoch 39/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 7.1626e-04 - mean_squared_error: 7.1626e-04
# Epoch 40/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 6.5583e-04 - mean_squared_error: 6.5583e-04
# Epoch 41/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 6.6750e-04 - mean_squared_error: 6.6750e-04
# Epoch 42/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 6.4518e-04 - mean_squared_error: 6.4518e-04
# Epoch 43/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 6.7385e-04 - mean_squared_error: 6.7385e-04
# Epoch 44/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 6.4320e-04 - mean_squared_error: 6.4320e-04
# Epoch 45/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 6.6505e-04 - mean_squared_error: 6.6505e-04
# Epoch 46/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 6.3630e-04 - mean_squared_error: 6.3630e-04
# Epoch 47/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - loss: 6.3615e-04 - mean_squared_error: 6.3615e-04
# Epoch 48/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 5.9958e-04 - mean_squared_error: 5.9958e-04
# Epoch 49/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 5.9161e-04 - mean_squared_error: 5.9161e-04
# Epoch 50/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 5.9534e-04 - mean_squared_error: 5.9534e-04
# Epoch 51/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 6.2559e-04 - mean_squared_error: 6.2559e-04
# Epoch 52/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 5.7308e-04 - mean_squared_error: 5.7308e-04
# Epoch 53/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 5.8538e-04 - mean_squared_error: 5.8538e-04
# Epoch 54/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - loss: 5.5160e-04 - mean_squared_error: 5.5160e-04
# Epoch 55/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 5.6057e-04 - mean_squared_error: 5.6057e-04
# Epoch 56/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 5.6390e-04 - mean_squared_error: 5.6390e-04
# Epoch 57/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 5.6008e-04 - mean_squared_error: 5.6008e-04
# Epoch 58/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 5.4655e-04 - mean_squared_error: 5.4655e-04
# Epoch 59/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 5.6240e-04 - mean_squared_error: 5.6240e-04
# Epoch 60/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 5.5612e-04 - mean_squared_error: 5.5612e-04
# Epoch 61/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 4.9857e-04 - mean_squared_error: 4.9857e-04
# Epoch 62/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 5.0112e-04 - mean_squared_error: 5.0112e-04
# Epoch 63/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 5.4318e-04 - mean_squared_error: 5.4318e-04
# Epoch 64/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 5.3609e-04 - mean_squared_error: 5.3609e-04
# Epoch 65/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 5.0694e-04 - mean_squared_error: 5.0694e-04
# Epoch 66/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 4.9929e-04 - mean_squared_error: 4.9929e-04
# Epoch 67/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 5.3878e-04 - mean_squared_error: 5.3878e-04
# Epoch 68/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 4.9242e-04 - mean_squared_error: 4.9242e-04
# Epoch 69/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 4.8024e-04 - mean_squared_error: 4.8024e-04
# Epoch 70/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 5.1435e-04 - mean_squared_error: 5.1435e-04
# Epoch 71/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.8091e-04 - mean_squared_error: 4.8091e-04
# Epoch 72/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 4.7338e-04 - mean_squared_error: 4.7338e-04
# Epoch 73/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.7565e-04 - mean_squared_error: 4.7565e-04
# Epoch 74/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 4.9371e-04 - mean_squared_error: 4.9371e-04
# Epoch 75/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.7145e-04 - mean_squared_error: 4.7145e-04
# Epoch 76/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 4.9171e-04 - mean_squared_error: 4.9171e-04
# Epoch 77/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 4.8674e-04 - mean_squared_error: 4.8674e-04
# Epoch 78/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.7596e-04 - mean_squared_error: 4.7596e-04
# Epoch 79/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 4.3916e-04 - mean_squared_error: 4.3916e-04
# Epoch 80/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 4.3434e-04 - mean_squared_error: 4.3434e-04
# Epoch 81/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 4.6787e-04 - mean_squared_error: 4.6787e-04
# Epoch 82/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.7497e-04 - mean_squared_error: 4.7497e-04
# Epoch 83/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 4.3473e-04 - mean_squared_error: 4.3473e-04
# Epoch 84/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 4.5343e-04 - mean_squared_error: 4.5343e-04
# Epoch 85/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.6540e-04 - mean_squared_error: 4.6540e-04
# Epoch 86/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.5589e-04 - mean_squared_error: 4.5589e-04
# Epoch 87/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 4.6327e-04 - mean_squared_error: 4.6327e-04
# Epoch 88/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 4.4369e-04 - mean_squared_error: 4.4369e-04
# Epoch 89/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.5708e-04 - mean_squared_error: 4.5708e-04
# Epoch 90/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.6311e-04 - mean_squared_error: 4.6311e-04
# Epoch 91/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 4.3556e-04 - mean_squared_error: 4.3556e-04
# Epoch 92/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 4.1190e-04 - mean_squared_error: 4.1190e-04
# Epoch 93/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 4.3594e-04 - mean_squared_error: 4.3594e-04
# Epoch 94/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 4.4521e-04 - mean_squared_error: 4.4521e-04
# Epoch 95/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.3281e-04 - mean_squared_error: 4.3281e-04
# Epoch 96/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - loss: 4.1727e-04 - mean_squared_error: 4.1727e-04
# Epoch 97/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 4.1698e-04 - mean_squared_error: 4.1698e-04
# Epoch 98/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 4.0582e-04 - mean_squared_error: 4.0582e-04
# Epoch 99/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 4.4029e-04 - mean_squared_error: 4.4029e-04
# Epoch 100/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 4.3510e-04 - mean_squared_error: 4.3510e-04
# Epoch 101/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 4.0749e-04 - mean_squared_error: 4.0749e-04
# Epoch 102/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.2988e-04 - mean_squared_error: 4.2988e-04
# Epoch 103/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 4.0756e-04 - mean_squared_error: 4.0756e-04
# Epoch 104/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 4.3846e-04 - mean_squared_error: 4.3846e-04
# Epoch 105/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 4.2955e-04 - mean_squared_error: 4.2955e-04
# Epoch 106/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.9200e-04 - mean_squared_error: 3.9200e-04
# Epoch 107/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 4.0189e-04 - mean_squared_error: 4.0189e-04
# Epoch 108/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - loss: 4.2632e-04 - mean_squared_error: 4.2632e-04
# Epoch 109/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - loss: 3.9785e-04 - mean_squared_error: 3.9785e-04
# Epoch 110/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 4.0374e-04 - mean_squared_error: 4.0374e-04
# Epoch 111/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.9817e-04 - mean_squared_error: 3.9817e-04
# Epoch 112/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 4.0221e-04 - mean_squared_error: 4.0221e-04
# Epoch 113/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.9515e-04 - mean_squared_error: 3.9515e-04
# Epoch 114/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 3.7661e-04 - mean_squared_error: 3.7661e-04
# Epoch 115/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 3.7796e-04 - mean_squared_error: 3.7796e-04
# Epoch 116/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - loss: 3.7797e-04 - mean_squared_error: 3.7797e-04
# Epoch 117/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.8070e-04 - mean_squared_error: 3.8070e-04
# Epoch 118/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 3.8493e-04 - mean_squared_error: 3.8493e-04
# Epoch 119/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 3.7543e-04 - mean_squared_error: 3.7543e-04
# Epoch 120/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.1540e-04 - mean_squared_error: 4.1540e-04
# Epoch 121/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 4.0948e-04 - mean_squared_error: 4.0948e-04
# Epoch 122/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 3.9798e-04 - mean_squared_error: 3.9798e-04
# Epoch 123/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 3.8650e-04 - mean_squared_error: 3.8650e-04
# Epoch 124/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 4.1616e-04 - mean_squared_error: 4.1616e-04
# Epoch 125/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 4.0958e-04 - mean_squared_error: 4.0958e-04
# Epoch 126/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - loss: 3.9919e-04 - mean_squared_error: 3.9919e-04
# Epoch 127/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.8543e-04 - mean_squared_error: 3.8543e-04
# Epoch 128/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.7025e-04 - mean_squared_error: 3.7025e-04
# Epoch 129/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 3.7632e-04 - mean_squared_error: 3.7632e-04
# Epoch 130/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 3.8164e-04 - mean_squared_error: 3.8164e-04
# Epoch 131/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - loss: 3.8628e-04 - mean_squared_error: 3.8628e-04
# Epoch 132/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 3.9521e-04 - mean_squared_error: 3.9521e-04
# Epoch 133/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.8079e-04 - mean_squared_error: 3.8079e-04
# Epoch 134/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 3.8683e-04 - mean_squared_error: 3.8683e-04
# Epoch 135/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.7464e-04 - mean_squared_error: 3.7465e-04
# Epoch 136/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 3.7007e-04 - mean_squared_error: 3.7007e-04
# Epoch 137/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.7953e-04 - mean_squared_error: 3.7953e-04
# Epoch 138/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.5744e-04 - mean_squared_error: 3.5744e-04
# Epoch 139/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 3.6196e-04 - mean_squared_error: 3.6196e-04
# Epoch 140/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 3.6993e-04 - mean_squared_error: 3.6993e-04
# Epoch 141/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.6983e-04 - mean_squared_error: 3.6983e-04
# Epoch 142/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 3.5379e-04 - mean_squared_error: 3.5379e-04
# Epoch 143/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 4.0982e-04 - mean_squared_error: 4.0982e-04
# Epoch 144/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.5809e-04 - mean_squared_error: 3.5809e-04
# Epoch 145/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 3.7084e-04 - mean_squared_error: 3.7084e-04
# Epoch 146/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 3.6157e-04 - mean_squared_error: 3.6157e-04
# Epoch 147/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 3.5307e-04 - mean_squared_error: 3.5307e-04
# Epoch 148/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 3.8562e-04 - mean_squared_error: 3.8562e-04
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.7582e-04 - mean_squared_error: 3.7582e-04
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 3.9869e-04 - mean_squared_error: 3.9869e-04
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.4090e-04 - mean_squared_error: 3.4090e-04
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.6922e-04 - mean_squared_error: 3.6922e-04
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 3.6155e-04 - mean_squared_error: 3.6155e-04
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 3.5003e-04 - mean_squared_error: 3.5003e-04
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.7698e-04 - mean_squared_error: 3.7698e-04
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 3.5908e-04 - mean_squared_error: 3.5908e-04
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.6513e-04 - mean_squared_error: 3.6513e-04
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.5230e-04 - mean_squared_error: 3.5230e-04
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.5937e-04 - mean_squared_error: 3.5937e-04
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 3.5139e-04 - mean_squared_error: 3.5139e-04
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.4981e-04 - mean_squared_error: 3.4981e-04
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 3.7541e-04 - mean_squared_error: 3.7541e-04
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 3.4097e-04 - mean_squared_error: 3.4097e-04
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.4634e-04 - mean_squared_error: 3.4634e-04
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.4699e-04 - mean_squared_error: 3.4699e-04
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 3.4621e-04 - mean_squared_error: 3.4621e-04
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.6015e-04 - mean_squared_error: 3.6015e-04
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 3.3863e-04 - mean_squared_error: 3.3863e-04
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 3.4350e-04 - mean_squared_error: 3.4350e-04
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.2807e-04 - mean_squared_error: 3.2807e-04
# Epoch 171/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 3.6125e-04 - mean_squared_error: 3.6125e-04
# Epoch 172/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.5579e-04 - mean_squared_error: 3.5579e-04
# Epoch 173/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.5571e-04 - mean_squared_error: 3.5571e-04
# Epoch 174/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 3.9007e-04 - mean_squared_error: 3.9007e-04
# Epoch 175/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 3.7986e-04 - mean_squared_error: 3.7986e-04
# Epoch 176/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.7837e-04 - mean_squared_error: 3.7837e-04
# Epoch 177/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 3.4796e-04 - mean_squared_error: 3.4796e-04
# Epoch 178/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.6323e-04 - mean_squared_error: 3.6323e-04
# Epoch 179/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.7729e-04 - mean_squared_error: 3.7729e-04
# Epoch 180/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 3.6664e-04 - mean_squared_error: 3.6664e-04
# Epoch 181/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.2676e-04 - mean_squared_error: 3.2676e-04
# Epoch 182/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.4762e-04 - mean_squared_error: 3.4762e-04
# Epoch 183/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.5003e-04 - mean_squared_error: 3.5003e-04
# Epoch 184/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 3.2994e-04 - mean_squared_error: 3.2994e-04
# Epoch 185/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.2796e-04 - mean_squared_error: 3.2796e-04
# Epoch 186/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 3.3690e-04 - mean_squared_error: 3.3690e-04
# Epoch 187/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 3.2644e-04 - mean_squared_error: 3.2644e-04
# Epoch 188/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 3.4123e-04 - mean_squared_error: 3.4123e-04
# Epoch 189/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 3.3457e-04 - mean_squared_error: 3.3457e-04
# Epoch 190/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.3122e-04 - mean_squared_error: 3.3122e-04
# Epoch 191/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 3.2113e-04 - mean_squared_error: 3.2113e-04
# Epoch 192/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.3608e-04 - mean_squared_error: 3.3608e-04
# Epoch 193/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.3171e-04 - mean_squared_error: 3.3171e-04
# Epoch 194/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 3.4656e-04 - mean_squared_error: 3.4656e-04
# Epoch 195/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.3926e-04 - mean_squared_error: 3.3926e-04
# Epoch 196/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - loss: 3.7429e-04 - mean_squared_error: 3.7429e-04
# Epoch 197/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.5052e-04 - mean_squared_error: 3.5052e-04
# Epoch 198/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 3.3838e-04 - mean_squared_error: 3.3838e-04
# Epoch 199/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 3.5440e-04 - mean_squared_error: 3.5440e-04
# Epoch 200/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 4.4229e-04 - mean_squared_error: 4.4229e-04

# %%
# 성능 확인을 위한 test model 선언

# %%
initializer = initializers.GlorotNormal()

def predict_model():
    SRCNN = Sequential()
    SRCNN.add(Conv2D(filters=n1, kernel_size=f1, activation='relu',
                     input_shape=(None, None,3), kernel_initializer=initializer, bias_initializer='zeros',
                     name='Conv1'))
    SRCNN.add(Conv2D(filters=n2, kernel_size=f2, activation='relu',
                     kernel_initializer=initializer, bias_initializer='zeros',
                     name='Conv2'))
    SRCNN.add(Conv2D(filters=n3, kernel_size=f3, activation='linear',
                     kernel_initializer=initializer, bias_initializer='zeros',
                     name='Conv3'))
    return SRCNN
    ## 예측준비완료

# %%
#
SRCNN_Test = predict_model()
# 모델 가중치를 .weights.h5 형식으로 저장
save_path = '/content/drive/MyDrive/srcnn/Set5.weights.h5'
SRCNN_Test.save_weights(save_path)

# 모델 가중치를 .weights.h5 형식으로 로드
save_path = '/content/drive/MyDrive/srcnn/Set5.weights.h5'
SRCNN_Test.load_weights(save_path)

# %%
# 이미지 비교
# Set5 에서 그림 선택(butterfly)
## bicubic으로 upscaling된 이미지는 모델학습 과정과 동일하게 처리해서 만들어준다.

# %%
import cv2

# 이미지 읽기
hr_img_path = '/content/drive/MyDrive/srcnn/Set5/Set5/butterfly.png'
hr_img = cv2.imread(hr_img_path)

# 이미지가 제대로 읽혔는지 확인
if hr_img is None:
    raise ValueError(f"Image not loaded. Check the file path or file format: {hr_img_path}")

# %%
# 이미지 색상 변환
hr_img = cv2.cvtColor(hr_img, cv2.COLOR_BGR2RGB)
print('img shape :{}'.format(hr_img.shape))
# Out:
# img shape :(256, 256, 3)

# %%
plt.imshow(hr_img)

# %%
hr_img = hr_img.astype('float')/255
temp_img = cv2.resize(hr_img, dsize=(0,0), fx=1/upscale_factor, fy=1/upscale_factor,
                      interpolation=cv2.INTER_AREA)
bicubic_img = cv2.resize(temp_img, dsize=(0,0), fx=upscale_factor, fy=upscale_factor,
                         interpolation=cv2.INTER_CUBIC)

input_img = bicubic_img[np.newaxis, :]
srcnn_img = SRCNN_Test.predict(input_img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step

# %%
# 3개 이미지를 한눈에 비교

# %%
fig, axes = plt.subplots(1,3,figsize=(10,5))

axes[0].imshow(hr_img)
axes[1].imshow(bicubic_img)
axes[2].imshow(np.squeeze(srcnn_img))

axes[0].set_title('hr_img')
axes[1].set_title('bicubic_img')
axes[2].set_title('srcnn_img')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'srcnn_img')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

print("SRCNN Image Min Value:", np.min(srcnn_img))
print("SRCNN Image Max Value:", np.max(srcnn_img))
# Out:
# SRCNN Image Min Value: -0.17116009
# SRCNN Image Max Value: 0.08576308
